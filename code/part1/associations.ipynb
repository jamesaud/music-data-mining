# %% [raw]
# 1. Associations rules between artists
#    - Pull data from DB
#
#    - Filter collaborations (require "&" and "Featuring")
#
#    - Split a song into artist list [[artist, artist, artist], ...]
#
#    - Disregard main artist for now
#
#    - Use Panda DF to store data
#
#    - Encoded with https://rasbt.github.io/mlxtend/user_guide/frequent_patterns/apriori/
#
#        DATAFRAME
#        ----------------------------------------------
#         artist  artist  artist  artist  artist
#        [True,   False,  True,   True,   False]
#        [True,   True,   True,   False,  False]
#        [True,   True,   True,   False,  False]
#
#
# 2. Word patterns associations with artists (lyrics API)
#
#    - Pull lyrics from https://developer.musixmatch.com/
#    - Clean data (remove stopwords, stemming, etc. using nltk)
#
#
#    1 Groups
#    --------
#    word group      artist   artist  artist  artist
#    [(hello)        True     True    True    False]
#    [(world)        True     True    False   False]
#
#
#    2 groups
#    ---------
#    [(hello, world)  True    True    False   False]

# %% [markdown]
# # Data and Filter Collaborations

# %%
# DB CONFIG
from pymongo import MongoClient

client = MongoClient('mongo', 27017)
db = client.music_db
songs_collection = db.songs

# %%
# Pull all songs from DB
songs = list(songs_collection.find())

# %%
# Filter Collaboration Songs 
SEPARATORS = ['&', 'Featuring', 'With', ',', 'Feat.']

def is_collaboration(artist):
    return any([word in artist for word in SEPARATORS])

collaborations = [song for song in songs if is_collaboration(song['artist'])]
collaborations[0]
# Out:
# {'_id': ObjectId('5b927851ea311f002198aadb'),
#  'title': 'I Like It',
#  'artist': 'Cardi B, Bad Bunny & J Balvin',
#  'peakPos': 5,
#  'lastPos': 0,
#  'weeks': 0,
#  'rank': 5,
#  'isNew': True,
#  'identifier': "'I Like It' by Cardi B, Bad Bunny & J Balvin",
#  'lyrics': {'error': 'Lyric no found, try again later.'}}

# %% [markdown]
# ### Artist List Format

# %%
import re
from typing import List

def clean(collaborators: List) -> List:
    return [artist.strip() for artist in collaborators]

def separate(artist: str) -> List:
    return re.split('|'.join(SEPARATORS), artist)

collaborators = [song['artist'] for song in collaborations]
collaborators = map(separate, collaborators)
collaborators = map(clean, collaborators)
collaborators = list(collaborators)
len(collaborators), collaborators[:10]
# Out:
# (2919,
#  [['Cardi B', 'Bad Bunny', 'J Balvin'],
#   ['6ix9ine', 'Nicki Minaj', 'Murda Beatz'],
#   ['Tyga', 'Offset'],
#   ['DJ Khaled', 'Justin Bieber', 'Chance The Rapper', 'Quavo'],
#   ['Post Malone', 'Ty Dolla $ign'],
#   ['Lil Baby', 'Drake'],
#   ['YG', '2 Chainz', 'Big Sean', 'Nicki Minaj'],
#   ['Nicki Minaj', 'Ariana Grande'],
#   ['Nicki Minaj', 'Lil Wayne'],
#   ['Nicki Minaj', 'Eminem', 'Labrinth']])

# %% [markdown]
# # Associations of Artists

# %%
from mlxtend.frequent_patterns import apriori
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori

dataset = collaborators
te = TransactionEncoder()
oht_ary = te.fit(dataset).transform(dataset, sparse=True)
df = pd.SparseDataFrame(oht_ary, columns=te.columns_, default_fill_value=False)
len(list(df.columns.values))
# Out:
# 2153

# %%
frequent_itemsets = apriori(df, min_support=0.001, use_colnames=True)   # 1/1000 out of 2919

# %%
# 563 3-artist collaborations, 2135 2-artist collaborations
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(len)
filtered_itemsets = frequent_itemsets.reset_index()

# %%
# 2 item ordered by support
two_itemsets = filtered_itemsets[(filtered_itemsets['length'] == 2)].sort_values(by='support', ascending=False)
print(len(two_itemsets), '2-Itemsets')
two_itemsets[:15]
# Out:
# 184 2-Itemsets
#      index   support                       itemsets  length
# 558    558  0.007194             (Drake, Lil Wayne)       2
# 547    547  0.005824         (Rick Ross, DJ Khaled)       2
# 521    521  0.005481           (Birdman, Lil Wayne)       2
# 620    620  0.004796  (The East Side Boyz, Lil Jon)       2
# 556    556  0.004796                (Drake, Future)       2
# 622    622  0.004111       (Nicki Minaj, Lil Wayne)       2
# 623    623  0.003768         (Lil Wayne, Rick Ross)       2
# 657    657  0.003426            (T-Pain, Rick Ross)       2
# 604    604  0.003083              (Jay-Z, R. Kelly)       2
# 590    590  0.003083           (Young Thug, Future)       2
# 610    610  0.003083                   (JoJo, K-Ci)       2
# 490    490  0.003083          (2 Chainz, Lil Wayne)       2
# 492    492  0.002741      (Metro Boomin, 21 Savage)       2
# 530    530  0.002741       (Lil Wayne, Chris Brown)       2
# 544    544  0.002741         (Lil Wayne, DJ Khaled)       2

# %%
# 3 item ordered by support
three_itemsets = filtered_itemsets[(filtered_itemsets['length'] == 3)].sort_values(by='support', ascending=False)
print(len(three_itemsets), '3-Itemsets')
three_itemsets
# Out:
# 14 3-Itemsets
#      index   support                                 itemsets  length
# 675    675  0.002055        (Lil Wayne, Rick Ross, DJ Khaled)       3
# 671    671  0.001370        (Metro Boomin, 21 Savage, Offset)       3
# 683    683  0.001370                      (Earth, Fire, Wind)       3
# 672    672  0.001028  (August Alsina, Chris Brown, DJ Khaled)       3
# 673    673  0.001028          (Birdman, Lil Wayne, Rick Ross)       3
# 674    674  0.001028            (Drake, Rick Ross, DJ Khaled)       3
# 676    676  0.001028      (Nicki Minaj, Rick Ross, DJ Khaled)       3
# 677    677  0.001028            (Plies, Rick Ross, DJ Khaled)       3
# 678    678  0.001028           (T-Pain, Rick Ross, DJ Khaled)       3
# 679    679  0.001028      (Trick Daddy, Rick Ross, DJ Khaled)       3
# 680    680  0.001028                      (Eve, Drag-On, DMX)       3
# 681    681  0.001028          (Drake, Nicki Minaj, Lil Wayne)       3
# 682    682  0.001028            (Drake, Lil Wayne, Rick Ross)       3
# 684    684  0.001028       (Eddie Levert, Sr., Gerald Levert)       3

# %%
# Ocurrences of a sample itemset
itemset = ('Rick Ross', 'Lil Wayne', 'DJ Khaled')
count = [artists for artists in collaborators if all([x in artists for x in itemset])]   
print("Number of occurences for", itemset, '=', len(count))
# Out:
# Number of occurences for ('Rick Ross', 'Lil Wayne', 'DJ Khaled') = 6

# %%
from mlxtend.frequent_patterns import association_rules
sets = association_rules(frequent_itemsets, metric="confidence", min_threshold=0.5)

sets['length'] = sets['antecedents'].apply(len)
sets[(sets['length'] == 2)].sort_values(by='confidence', ascending=False)
# Out:
#                        antecedents      consequents  antecedent support  \
# 83              (Plies, DJ Khaled)      (Rick Ross)            0.001028
# 82              (Plies, Rick Ross)      (DJ Khaled)            0.001028
# 99   (Eddie Levert, Gerald Levert)            (Sr.)            0.001028
# 98             (Sr., Eddie Levert)  (Gerald Levert)            0.001028
# 94                    (Fire, Wind)          (Earth)            0.001370
# 93                   (Earth, Wind)           (Fire)            0.001370
# 92                   (Earth, Fire)           (Wind)            0.001370
# 89                  (Drag-On, DMX)            (Eve)            0.001028
# 88                      (Eve, DMX)        (Drag-On)            0.001028
# 87                  (Eve, Drag-On)            (DMX)            0.001028
# 86        (Trick Daddy, DJ Khaled)      (Rick Ross)            0.001028
# 85        (Trick Daddy, Rick Ross)      (DJ Khaled)            0.001028
# 100           (Sr., Gerald Levert)   (Eddie Levert)            0.001028
# 81        (Nicki Minaj, DJ Khaled)      (Rick Ross)            0.001028
# 74      (August Alsina, DJ Khaled)    (Chris Brown)            0.001028
# 73    (August Alsina, Chris Brown)      (DJ Khaled)            0.001028
# 72             (21 Savage, Offset)   (Metro Boomin)            0.001370
# 84             (T-Pain, DJ Khaled)      (Rick Ross)            0.001370
# 79          (Lil Wayne, DJ Khaled)      (Rick Ross)            0.002741
# 77              (Drake, DJ Khaled)      (Rick Ross)            0.001713
# 71          (Metro Boomin, Offset)      (21 Savage)            0.002398
# 78          (Lil Wayne, Rick Ross)      (DJ Khaled)            0.003768
# 80        (Nicki Minaj, Rick Ross)      (DJ Khaled)            0.002055
# 91            (Drake, Nicki Minaj)      (Lil Wayne)            0.002055
# 76            (Birdman, Rick Ross)      (Lil Wayne)            0.002055
# 75        (Chris Brown, DJ Khaled)  (August Alsina)            0.002055
# 70       (Metro Boomin, 21 Savage)         (Offset)            0.002741
#
#      consequent support   support  confidence        lift  leverage  \
# 83             0.029462  0.001028    1.000000   33.941860  0.000997
# 82             0.012333  0.001028    1.000000   81.083333  0.001015
# 99             0.001370  0.001028    1.000000  729.750000  0.001026
# 98             0.002055  0.001028    1.000000  486.500000  0.001026
# 94             0.001370  0.001370    1.000000  729.750000  0.001368
# 93             0.001370  0.001370    1.000000  729.750000  0.001368
# 92             0.001370  0.001370    1.000000  729.750000  0.001368
# 89             0.006166  0.001028    1.000000  162.166667  0.001021
# 88             0.001713  0.001028    1.000000  583.800000  0.001026
# 87             0.006509  0.001028    1.000000  153.631579  0.001021
# 86             0.029462  0.001028    1.000000   33.941860  0.000997
# 85             0.012333  0.001028    1.000000   81.083333  0.001015
# 100            0.001028  0.001028    1.000000  973.000000  0.001027
# 81             0.029462  0.001028    1.000000   33.941860  0.000997
# 74             0.025694  0.001028    1.000000   38.920000  0.001001
# 73             0.012333  0.001028    1.000000   81.083333  0.001015
# 72             0.004111  0.001370    1.000000  243.250000  0.001365
# 84             0.029462  0.001028    0.750000   25.456395  0.000987
# 79             0.029462  0.002055    0.750000   25.456395  0.001975
# 77             0.029462  0.001028    0.600000   20.365116  0.000977
# 71             0.005481  0.001370    0.571429  104.250000  0.001357
# 78             0.012333  0.002055    0.545455   44.227273  0.002009
# 80             0.012333  0.001028    0.500000   40.541667  0.001002
# 91             0.045221  0.001028    0.500000   11.056818  0.000935
# 76             0.045221  0.001028    0.500000   11.056818  0.000935
# 75             0.003083  0.001028    0.500000  162.166667  0.001021
# 70             0.004796  0.001370    0.500000  104.250000  0.001357
#
#      conviction  length
# 83          inf       2
# 82          inf       2
# 99          inf       2
# 98          inf       2
# 94          inf       2
# 93          inf       2
# 92          inf       2
# 89          inf       2
# 88          inf       2
# 87          inf       2
# 86          inf       2
# 85          inf       2
# 100         inf       2
# 81          inf       2
# 74          inf       2
# 73          inf       2
# 72          inf       2
# 84     3.882151       2
# 79     3.882151       2
# 77     2.426345       2
# 71     2.320544       2
# 78     2.172867       2
# 80     1.975334       2
# 91     1.909558       2
# 76     1.909558       2
# 75     1.993834       2
# 70     1.990408       2
