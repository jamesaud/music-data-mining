# %% [raw]
# 2. Word patterns associations with artists (lyrics API)
#
#    - Pull lyrics from https://developer.musixmatch.com/
#    - Clean data (remove stopwords, stemming, punctuation, strip, [HOOK] (DJ Scratches) using nltk)
#
#
#    1 Groups
#    --------
#    word group      artist   artist  artist  artist
#    [(hello)        True     True    True    False]
#    [(world)        True     True    False   False]
#
#
#    2 groups
#    ---------
#    [(hello, world)  True    True    False   False]

# %%
import requests
from pymongo import MongoClient
from urllib.parse import urljoin
from pprint import pprint
import nltk
import json

# %% [markdown]
# # Retrieve Lyrics Via API

# %%
# DB CONFIG
client = MongoClient('mongo', 27017)
db = client.music_db
songs_collection = db.songs

# %%
# Pull all songs from DB
songs = list(songs_collection.find())

# %%
def has_lyrics(song):
    if not song.get('lyrics'):
        return False
    
    if song.get('lyrics') == 'null':
        return False

    if song.get('lyrics').get('error'):
        return False
        
    
    return True

songs = [song for song in songs if has_lyrics(song)]

# %% [markdown]
# # Clean Lyrics

# %%
import re
import string
from nltk.tokenize import WhitespaceTokenizer
from nltk.stem import PorterStemmer, WordNetLemmatizer, SnowballStemmer
from nltk.corpus import stopwords
from typing import List

STOPWORDS = set(stopwords.words('english'))
stemmer = SnowballStemmer('english')
lemmatizer = WordNetLemmatizer()

def clean(word):
    chars = [char for char in word if char not in string.punctuation]  # Remove Punctuation
    word = "".join(chars)
    word = word.lower()   # Lowercase
    return word    


def tokenize_lyrics(lyrics: str):
    """ Takes lyrics in string format, returns list of words """
    replacement_patterns = (r'\[.*?\]',    # Between Brackets
                           )    
    lyrics_clean = re.sub('|'.join(replacement_patterns), '', lyrics)
    tokenizer = WhitespaceTokenizer()
    tokens = tokenizer.tokenize(lyrics_clean)
    
    # Split words with hyphens
    for word in tokens:
        if '-' in word:
            i = tokens.index(word)
            tokens = tokens[:i] + word.split('-') + tokens[i+1:]
        
    tokens = filter(lambda token: token != '', tokens)
    return list(tokens)


def is_stopword(word: str):
    return word in STOPWORDS


def tokenize(lyrics, stopwords=True, lemandstem=True):
    tokens = tokenize_lyrics(lyrics)
    tokens = map(clean, tokens)
    if stopwords:
        tokens = [word for word in tokens if not is_stopword(word)]
    if lemandstem:
        tokens = map(lemmatizer.lemmatize, tokens)
        tokens = map(stemmer.stem, tokens)
        tokens = map(lemmatizer.lemmatize, tokens)
    tokens = list(tokens)
    return tokens


def add_tokenization_to_track(track):
    track['lyrics']['tokens'] = tokenize(track['lyrics']['result']['track']['text'])
    return track
    
tokenizations = list(map(add_tokenization_to_track, songs))

# %% [markdown]
# # Associations

# %%
# Format properly
tokens = [track['lyrics']['tokens'] for track in tokenizations]

def join_tokens(tokens, group):
    new_tokens = []
    for i in range(0, len(tokens) - group):
        word_set = [tokens[i + j] for j in range(group)] 
        new_tokens.append(" ".join(word_set))
    return new_tokens

tokens = [join_tokens(tokenset, 2) for tokenset in tokens]

# %%
from mlxtend.frequent_patterns import apriori
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori

dataset = tokens
te = TransactionEncoder()
oht_ary = te.fit(dataset).transform(dataset, sparse=True)
df = pd.SparseDataFrame(oht_ary, columns=te.columns_, default_fill_value=False)

# %%
frequent_itemsets = apriori(df, min_support=.7, use_colnames=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-49958b9888f9> in <module>()
# ----> 1 frequent_itemsets = apriori(df, min_support=.7, use_colnames=True)
#
# /opt/conda/lib/python3.6/site-packages/mlxtend/frequent_patterns/apriori.py in apriori(df, min_support, use_colnames, max_len, n_jobs)
#     104     """
#     105     allowed_val = {0, 1, True, False}
# --> 106     unique_val = np.unique(df.values.ravel())
#     107     for val in unique_val:
#     108         if val not in allowed_val:
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/generic.py in values(self)
#    4631         """
#    4632         self._consolidate_inplace()
# -> 4633         return self._data.as_array(transpose=self._AXIS_REVERSED)
#    4634
#    4635     @property
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py in as_array(self, transpose, items)
#    3947             arr = mgr.blocks[0].get_values()
#    3948         else:
# -> 3949             arr = mgr._interleave()
#    3950
#    3951         return arr.transpose() if transpose else arr
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py in _interleave(self)
#    3976         for blk in self.blocks:
#    3977             rl = blk.mgr_locs
# -> 3978             result[rl.indexer] = blk.get_values(dtype)
#    3979             itemmask[rl.indexer] = 1
#    3980
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/internals.py in get_values(self, dtype)
#    1751     def get_values(self, dtype=None):
#    1752         """ need to to_dense myself (and always return a ndim sized object) """
# -> 1753         values = self.values.to_dense()
#    1754         if values.ndim == self.ndim - 1:
#    1755             values = values.reshape((1,) + values.shape)
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/sparse/array.py in to_dense(self, fill)
#     388                            "will be removed in a future version."),
#     389                           FutureWarning, stacklevel=2)
# --> 390         return self.values
#     391
#     392     def __iter__(self):
#
# /opt/conda/lib/python3.6/site-packages/pandas/core/sparse/array.py in values(self)
#     336         """
#     337         output = np.empty(len(self), dtype=self.dtype)
# --> 338         int_index = self.sp_index.to_int_index()
#     339         output.fill(self.fill_value)
#     340         output.put(int_index.indices, self)
#
# KeyboardInterrupt:

# %%
frequent_itemsets['length'] = frequent_itemsets['itemsets'].apply(len)
frequent_itemsets

# %%
def itemset_by_length(df, length):
    length_itemsets = df[(df['length'] == length)].sort_values(by='support', ascending=False)
    return length_itemsets

itemset_by_length(frequent_itemsets, 1)

# %% [markdown]
# # New

# %%
from collections import Counter
from pandas import DataFrame

def songs_by(artist):
    return [song for song in songs if artist == song['artist']]

drake = songs_by('Drake')
eminem = songs_by('Eminem')

def songs_to_counts(songs: List[List[str]]):
    word_counts = Counter()
    for song in songs:
        word_counts.update(Counter(song))
    return word_counts

def token_list(track):
    return track['lyrics']['tokens']

tokens = list(map(token_list, eminem))
counts = songs_to_counts(tokens)
total = sum(counts.values())

df = DataFrame.from_dict(counts, orient='index', columns=['count'])
df['frequency'] = df['count'].apply(lambda x: x/total)
df.sort_values(by='frequency', ascending=False)
# Out:
#             count  frequency
# im            260   0.024579
# like          163   0.015409
# dont          125   0.011817
# go            119   0.011250
# get           117   0.011061
# caus          109   0.010304
# know           90   0.008508
# back           84   0.007941
# cant           78   0.007374
# ah             76   0.007185
# fuck           75   0.007090
# never          74   0.006996
# let            74   0.006996
# shadi          69   0.006523
# superman       68   0.006428
# make           67   0.006334
# shit           67   0.006334
# say            64   0.006050
# name           62   0.005861
# one            61   0.005767
# got            60   0.005672
# see            55   0.005199
# your           54   0.005105
# slim           54   0.005105
# think          49   0.004632
# time           49   0.004632
# come           48   0.004538
# look           47   0.004443
# feel           47   0.004443
# ill            46   0.004349
# ...           ...        ...
# whatch          1   0.000095
# betcha          1   0.000095
# exist           1   0.000095
# plottin         1   0.000095
# grasp           1   0.000095
# git             1   0.000095
# seek            1   0.000095
# reveng          1   0.000095
# sympathi        1   0.000095
# friendship      1   0.000095
# apolog          1   0.000095
# empathi         1   0.000095
# appoint         1   0.000095
# disappoint      1   0.000095
# sight           1   0.000095
# saliva          1   0.000095
# address         1   0.000095
# profil          1   0.000095
# 45              1   0.000095
# frickin         1   0.000095
# tail            1   0.000095
# puff            1   0.000095
# hidin           1   0.000095
# resent          1   0.000095
# pent            1   0.000095
# harbor          1   0.000095
# him             1   0.000095
# heidi           1   0.000095
# cha             1   0.000095
# du              1   0.000095
#
# [2767 rows x 2 columns]

# %%
one = songs_by('Kanye West')
two = songs_by('Eminem')

num_docs = 5

one_tokens = list(map(token_list, one))
two_tokens = list(map(token_list, two))

one_docs = list(map(" ".join, one_tokens))[:num_docs]
two_docs = list(map(" ".join, two_tokens))[:num_docs]

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
documents = one_docs + two_docs
tfidf_vectorizer = TfidfVectorizer()
tfidf_matrix = tfidf_vectorizer.fit_transform(documents)
print(tfidf_matrix.shape)
# Out:
# (10, 1582)

# %% [raw]
# TF-IDF matrix (tfidf_matrix) for each document (the number of rows of the matrix) with 11 tf-idf terms (the number of columns from the matrix)

# %%
from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances

similarity = cosine_similarity(tfidf_matrix, tfidf_matrix)

# %%
import numpy as np
import seaborn as sns
import matplotlib.pylab as plt
# %matplotlib inline

plt.figure(figsize=(15,10))
ax = sns.heatmap(similarity, linewidth=0.8)
plt.show()
